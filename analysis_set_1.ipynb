# %% [markdown]
# # Comparative analysis of simulations set 1
#
# Configuration:
# - 60 days
# - only SecondaryFollow
# - probability of secondary follow = 0.25
# - the same population for all simulations

# %%
from social_graph.pipeline import *
import sqlite3
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
conn3 = sqlite3.connect("data/experiment_set_1/database_server_3.db")
conn4 = sqlite3.connect("data/experiment_set_1/database_server_4.db")
conn5 = sqlite3.connect("data/experiment_set_1/database_server_5.db")

connb1 = sqlite3.connect("data/experiment_set_1/database_server_b1.db")
connb2 = sqlite3.connect("data/experiment_set_1/database_server_b2.db")
connb3 = sqlite3.connect("data/experiment_set_1/database_server_b3.db")

# %% [markdown]
# ## Simulation b1

# %%
personaeb1, features_df_b1, followb1 = run_simulation_preprocessing(conn3, label='Simulation_b1')
# Out:
# ...
# Running Simulation_b1...
#
# Data loading ...
#
# Number of users: 1000
# Total actions: 16424
# Follow actions: 12317
# Unfollow actions: 4107
# Number of rounds: 61
# Number of posts: 140111
#
# Checking professions consistency ...
#
# Number of professions not in map: 0
# Professions: set()
#
# Creating persona and features DataFrames ...
#
# Features encoded size: (1000, 25)
#
# Searching best number of persona ...
#
# k=2 silhouette=0.0816
# k=3 silhouette=0.0961
# k=4 silhouette=0.1382
# k=5 silhouette=0.0972
# k=6 silhouette=0.1022
# k=7 silhouette=0.1138
# k=8 silhouette=0.1054
# k=9 silhouette=0.1170
# Done!

# %%
k_best = 4

description_b1, persona_dict = cluster_persona_and_analyse(personaeb1, features_df_b1, k_best, label='Simulation_b1')
# Out:
# ...
# Running Simulation_b1...
#
# Persona creation ...
#
# persona
# Persona_3    257
# Persona_4    255
# Persona_2    248
# Persona_1    240
# Name: count, dtype: int64
#
# Persona analysis ...
#
# Features significance regarding personae:
# openness: 0.3435675936396342
# conscientiousness: 0.3511976933463813
# extroversion: 1.2544441350646485e-105
# agreeableness: 7.220419696004772e-111
# neuroticism: 1.7994208765314067e-216
# age: 0.005018962218650817
# profession: 0.07484624611831255

# %%
global_metrics_b1, summary_b1 = build_graph_and_analyse(followb1, persona_dict, label='Simulation_b1')
# Out:
# ...
# Running Simulation_b1...
#
# Graph creation ...
#
# Number of nodes: 892
# Number of edges: 10230
# Number of connective components: 1
# Components sizes: [892]
#
# Global metrics ...
#
# Mean degree: 22.94
# Density: 0.0129
# Diameter: 6
# Avg. shortest path: 2.822
# Modularity score: 0.156
# Persona assortativity: -0.002826403667822731
#
# Local metrics ...
#
#
# Statistical check (metrics vs. persona) ...
#
# in_degree statistics: p = 0.0384
# out_degree statistics: p = 0.2360
# total_degree statistics: p = 0.1014
# betweenness statistics: p = 0.0354
# eigenvector statistics: p = 0.4197
# pagerank statistics: p = 0.0313
# kcore statistics: p = 0.1214

# %%
summary_b1
# Out:
#            n_nodes  mean_in_degree  mean_out_degree  mean_total_degree  \
# persona
# Persona_1      214       13.813084        13.084112          26.897196
# Persona_2      219       10.589041        11.228311          21.817352
# Persona_3      225       12.048889        11.462222          23.511111
# Persona_4      234        9.589744        10.222222          19.811966
#
#            mean_betweenness  median_betweenness  mean_pagerank  mean_kcore  \
# persona
# Persona_1          0.002148            0.000378       0.001309   11.574766
# Persona_2          0.001921            0.000163       0.001054   10.100457
# Persona_3          0.002119            0.000240       0.001168   10.186667
# Persona_4          0.001507            0.000088       0.000966    9.405983
#
#            pagerank_ratio     Simulation
# persona
# Persona_1        1.167879  Simulation_b1
# Persona_2        0.940593  Simulation_b1
# Persona_3        1.041861  Simulation_b1
# ...

# %% [markdown]
# ## Simulation b2

# %%
personaeb2, features_df_b2, followb2 = run_simulation_preprocessing(connb2, label='Simulation_b2')
# Out:
# ...
# Running Simulation_b2...
#
# Data loading ...
#
# Number of users: 1000
# Total actions: 17434
# Follow actions: 12977
# Unfollow actions: 4457
# Number of rounds: 61
# Number of posts: 148363
#
# Checking professions consistency ...
#
# Number of professions not in map: 0
# Professions: set()
#
# Creating persona and features DataFrames ...
#
# Features encoded size: (1000, 25)
#
# Searching best number of persona ...
#
# k=2 silhouette=0.0816
# k=3 silhouette=0.0961
# k=4 silhouette=0.1382
# k=5 silhouette=0.0972
# k=6 silhouette=0.1022
# k=7 silhouette=0.1138
# k=8 silhouette=0.1054
# k=9 silhouette=0.1170
# Done!

# %%
k_best = 4

description_b2, persona_dict = cluster_persona_and_analyse(personaeb2, features_df_b2, k_best, label='Simulation_b2')
# Out:
# ...
# Running Simulation_b2...
#
# Persona creation ...
#
# persona
# Persona_3    257
# Persona_4    255
# Persona_2    248
# Persona_1    240
# Name: count, dtype: int64
#
# Persona analysis ...
#
# Features significance regarding personae:
# openness: 0.3435675936396342
# conscientiousness: 0.3511976933463813
# extroversion: 1.2544441350646485e-105
# agreeableness: 7.220419696004772e-111
# neuroticism: 1.7994208765314067e-216
# age: 0.005018962218650817
# profession: 0.07484624611831255

# %%
global_metrics_b2, summary_b2 = build_graph_and_analyse(followb2, persona_dict, label='Simulation_b2')
# Out:
# ...
# Running Simulation_b2...
#
# Graph creation ...
#
# Number of nodes: 895
# Number of edges: 10589
# Number of connective components: 1
# Components sizes: [895]
#
# Global metrics ...
#
# Mean degree: 23.66
# Density: 0.0132
# Diameter: 7
# Avg. shortest path: 2.809
# Modularity score: 0.157
# Persona assortativity: -0.0028462014605278333
#
# Local metrics ...
#
#
# Statistical check (metrics vs. persona) ...
#
# in_degree statistics: p = 0.0119
# out_degree statistics: p = 0.2010
# total_degree statistics: p = 0.0703
# betweenness statistics: p = 0.1868
# eigenvector statistics: p = 0.0405
# pagerank statistics: p = 0.0183
# kcore statistics: p = 0.0528

# %%
summary_b2
# Out:
#            n_nodes  mean_in_degree  mean_out_degree  mean_total_degree  \
# persona
# Persona_1      215       14.418605        14.190698          28.609302
# Persona_2      232        8.719828         9.590517          18.310345
# Persona_3      220       13.577273        12.068182          25.645455
# Persona_4      228       10.872807        11.657895          22.530702
#
#            mean_betweenness  median_betweenness  mean_pagerank  mean_kcore  \
# persona
# Persona_1          0.002125            0.000182       0.001313   12.413953
# Persona_2          0.001325            0.000093       0.000878    9.581897
# Persona_3          0.002268            0.000120       0.001255   10.459091
# Persona_4          0.001733            0.000082       0.001044   10.201754
#
#            pagerank_ratio     Simulation
# persona
# Persona_1        1.174880  Simulation_b2
# Persona_2        0.786022  Simulation_b2
# Persona_3        1.122788  Simulation_b2
# ...

# %% [markdown]
# ## Simulation b3

# %%
personaeb3, features_df_b3, followb3 = run_simulation_preprocessing(connb3, label='Simulation_b3')
# Out:
# ...
# Running Simulation_b3...
#
# Data loading ...
#
# Number of users: 1000
# Total actions: 16690
# Follow actions: 12468
# Unfollow actions: 4222
# Number of rounds: 61
# Number of posts: 134356
#
# Checking professions consistency ...
#
# Number of professions not in map: 0
# Professions: set()
#
# Creating persona and features DataFrames ...
#
# Features encoded size: (1000, 25)
#
# Searching best number of persona ...
#
# k=2 silhouette=0.0816
# k=3 silhouette=0.0961
# k=4 silhouette=0.1382
# k=5 silhouette=0.0972
# k=6 silhouette=0.1022
# k=7 silhouette=0.1138
# k=8 silhouette=0.1054
# k=9 silhouette=0.1170
# Done!

# %%
k_best = 4

description_b3, persona_dict = cluster_persona_and_analyse(personaeb3, features_df_b3, k_best, label='Simulation_b3')
# Out:
# ...
# Running Simulation_b3...
#
# Persona creation ...
#
# persona
# Persona_3    257
# Persona_4    255
# Persona_2    248
# Persona_1    240
# Name: count, dtype: int64
#
# Persona analysis ...
#
# Features significance regarding personae:
# openness: 0.3435675936396342
# conscientiousness: 0.3511976933463813
# extroversion: 1.2544441350646485e-105
# agreeableness: 7.220419696004772e-111
# neuroticism: 1.7994208765314067e-216
# age: 0.005018962218650817
# profession: 0.07484624611831255

# %%
global_metrics_b3, summary_b3 = build_graph_and_analyse(followb3, persona_dict, label='Simulation_b3')
# Out:
# ...
# Running Simulation_b3...
#
# Graph creation ...
#
# Number of nodes: 891
# Number of edges: 10281
# Number of connective components: 1
# Components sizes: [891]
#
# Global metrics ...
#
# Mean degree: 23.08
# Density: 0.0130
# Diameter: 7
# Avg. shortest path: 2.801
# Modularity score: 0.161
# Persona assortativity: 0.002136933583473898
#
# Local metrics ...
#
#
# Statistical check (metrics vs. persona) ...
#
# in_degree statistics: p = 0.2320
# out_degree statistics: p = 0.4628
# total_degree statistics: p = 0.3993
# betweenness statistics: p = 0.3685
# eigenvector statistics: p = 0.3197
# pagerank statistics: p = 0.1958
# kcore statistics: p = 0.3750

# %%
summary_b3
# Out:
#            n_nodes  mean_in_degree  mean_out_degree  mean_total_degree  \
# persona
# Persona_1      223       13.645740        13.735426          27.381166
# Persona_2      218        9.711009         9.885321          19.596330
# Persona_3      229       12.358079        11.331878          23.689956
# Persona_4      221       10.366516        11.167421          21.533937
#
#            mean_betweenness  median_betweenness  mean_pagerank  mean_kcore  \
# persona
# Persona_1          0.002309            0.000375       0.001275   11.941704
# Persona_2          0.001632            0.000085       0.000979    9.761468
# Persona_3          0.002207            0.000202       0.001203    9.868996
# Persona_4          0.001771            0.000253       0.001026   10.475113
#
#            pagerank_ratio     Simulation
# persona
# Persona_1        1.136342  Simulation_b3
# Persona_2        0.872111  Simulation_b3
# Persona_3        1.072026  Simulation_b3
# ...

# %% [markdown]
# ## Simulation 3

# %%
personae3, features_df_3, follow3 = run_simulation_preprocessing(conn3, label='Simulation_3')
# Out:
# ...
# Running Simulation_3...
#
# Data loading ...
#
# Number of users: 1000
# Total actions: 16424
# Follow actions: 12317
# Unfollow actions: 4107
# Number of rounds: 61
# Number of posts: 140111
#
# Checking professions consistency ...
#
# Number of professions not in map: 0
# Professions: set()
#
# Creating persona and features DataFrames ...
#
# Features encoded size: (1000, 25)
#
# Searching best number of persona ...
#
# k=2 silhouette=0.0816
# k=3 silhouette=0.0961
# k=4 silhouette=0.1382
# k=5 silhouette=0.0972
# k=6 silhouette=0.1022
# k=7 silhouette=0.1138
# k=8 silhouette=0.1054
# k=9 silhouette=0.1170
# Done!

# %%
k_best = 4

description_3, persona_dict = cluster_persona_and_analyse(personae3, features_df_3, k_best, label='Simulation_3')
# Out:
# ...
# Running Simulation_3...
#
# Persona creation ...
#
# persona
# Persona_3    257
# Persona_4    255
# Persona_2    248
# Persona_1    240
# Name: count, dtype: int64
#
# Persona analysis ...
#
# Features significance regarding personae:
# openness: 0.3435675936396342
# conscientiousness: 0.3511976933463813
# extroversion: 1.2544441350646485e-105
# agreeableness: 7.220419696004772e-111
# neuroticism: 1.7994208765314067e-216
# age: 0.005018962218650817
# profession: 0.07484624611831255

# %%
global_metrics_3, summary_3 = build_graph_and_analyse(follow3, persona_dict, label='Simulation_3')
# Out:
# ...
# Running Simulation_3...
#
# Graph creation ...
#
# Number of nodes: 892
# Number of edges: 10230
# Number of connective components: 1
# Components sizes: [892]
#
# Global metrics ...
#
# Mean degree: 22.94
# Density: 0.0129
# Diameter: 6
# Avg. shortest path: 2.822
# Modularity score: 0.159
# Persona assortativity: -0.002826403667822731
#
# Local metrics ...
#
#
# Statistical check (metrics vs. persona) ...
#
# in_degree statistics: p = 0.0384
# out_degree statistics: p = 0.2360
# total_degree statistics: p = 0.1014
# betweenness statistics: p = 0.0354
# eigenvector statistics: p = 0.4200
# pagerank statistics: p = 0.0313
# kcore statistics: p = 0.1214

# %%
summary_3
# Out:
#            n_nodes  mean_in_degree  mean_out_degree  mean_total_degree  \
# persona
# Persona_1      214       13.813084        13.084112          26.897196
# Persona_2      219       10.589041        11.228311          21.817352
# Persona_3      225       12.048889        11.462222          23.511111
# Persona_4      234        9.589744        10.222222          19.811966
#
#            mean_betweenness  median_betweenness  mean_pagerank  mean_kcore  \
# persona
# Persona_1          0.002148            0.000378       0.001309   11.574766
# Persona_2          0.001921            0.000163       0.001054   10.100457
# Persona_3          0.002119            0.000240       0.001168   10.186667
# Persona_4          0.001507            0.000088       0.000966    9.405983
#
#            pagerank_ratio    Simulation
# persona
# Persona_1        1.167879  Simulation_3
# Persona_2        0.940593  Simulation_3
# Persona_3        1.041861  Simulation_3
# Persona_4        0.861818  Simulation_3

# %% [markdown]
# ## Simulation 4

# %%
personae, features_df, follow = run_simulation_preprocessing(conn4, label='Simulation_4')
# Out:
# ...
# Running Simulation_4...
#
# Data loading ...
#
# Number of users: 1000
# Total actions: 16867
# Follow actions: 12603
# Unfollow actions: 4264
# Number of rounds: 61
# Number of posts: 143114
#
# Checking professions consistency ...
#
# Number of professions not in map: 0
# Professions: set()
#
# Creating persona and features DataFrames ...
#
# Features encoded size: (1000, 25)
#
# Searching best number of persona ...
#
# k=2 silhouette=0.0816
# k=3 silhouette=0.0961
# k=4 silhouette=0.1382
# k=5 silhouette=0.0972
# k=6 silhouette=0.1022
# k=7 silhouette=0.1138
# k=8 silhouette=0.1054
# k=9 silhouette=0.1170
# Done!

# %%
k_best = 4

description_4, persona_dict = cluster_persona_and_analyse(personae, features_df, k_best, label='Simulation_4')
# Out:
# ...
# Running Simulation_4...
#
# Persona creation ...
#
# persona
# Persona_3    257
# Persona_4    255
# Persona_2    248
# Persona_1    240
# Name: count, dtype: int64
#
# Persona analysis ...
#
# Features significance regarding personae:
# openness: 0.3435675936396342
# conscientiousness: 0.3511976933463813
# extroversion: 1.2544441350646485e-105
# agreeableness: 7.220419696004772e-111
# neuroticism: 1.7994208765314067e-216
# age: 0.005018962218650817
# profession: 0.07484624611831255

# %%
global_metrics_4, summary_4 = build_graph_and_analyse(follow, persona_dict, label='Simulation_4')
# Out:
# ...
# Running Simulation_4...
#
# Graph creation ...
#
# Number of nodes: 888
# Number of edges: 10277
# Number of connective components: 1
# Components sizes: [888]
#
# Global metrics ...
#
# Mean degree: 23.15
# Density: 0.0130
# Diameter: 6
# Avg. shortest path: 2.789
# Modularity score: 0.158
# Persona assortativity: -0.0012870329849504444
#
# Local metrics ...
#
#
# Statistical check (metrics vs. persona) ...
#
# in_degree statistics: p = 0.4119
# out_degree statistics: p = 0.4176
# total_degree statistics: p = 0.6362
# betweenness statistics: p = 0.6375
# eigenvector statistics: p = 0.5102
# pagerank statistics: p = 0.4591
# kcore statistics: p = 0.5644

# %% [markdown]
# ## Simulation 5

# %%
personae, features_df, follow = run_simulation_preprocessing(conn5, label='Simulation_5')
# Out:
# ...
# Running Simulation_5...
#
# Data loading ...
#
# Number of users: 1000
# Total actions: 16799
# Follow actions: 12468
# Unfollow actions: 4331
# Number of rounds: 61
# Number of posts: 140953
#
# Checking professions consistency ...
#
# Number of professions not in map: 0
# Professions: set()
#
# Creating persona and features DataFrames ...
#
# Features encoded size: (1000, 25)
#
# Searching best number of persona ...
#
# k=2 silhouette=0.0816
# k=3 silhouette=0.0961
# k=4 silhouette=0.1382
# k=5 silhouette=0.0972
# k=6 silhouette=0.1022
# k=7 silhouette=0.1138
# k=8 silhouette=0.1054
# k=9 silhouette=0.1170
# Done!

# %%
k_best = 4

description_5, persona_dict = cluster_persona_and_analyse(personae, features_df, k_best, label='Simulation_5')
# Out:
# ...
# Running Simulation_5...
#
# Persona creation ...
#
# persona
# Persona_3    257
# Persona_4    255
# Persona_2    248
# Persona_1    240
# Name: count, dtype: int64
#
# Persona analysis ...
#
# Features significance regarding personae:
# openness: 0.3435675936396342
# conscientiousness: 0.3511976933463813
# extroversion: 1.2544441350646485e-105
# agreeableness: 7.220419696004772e-111
# neuroticism: 1.7994208765314067e-216
# age: 0.005018962218650817
# profession: 0.07484624611831255

# %%
global_metrics_5, summary_5 = build_graph_and_analyse(follow, persona_dict, label='Simulation_5')
# Out:
# ...
# Running Simulation_5...
#
# Graph creation ...
#
# Number of nodes: 903
# Number of edges: 10148
# Number of connective components: 1
# Components sizes: [903]
#
# Global metrics ...
#
# Mean degree: 22.48
# Density: 0.0125
# Diameter: 6
# Avg. shortest path: 2.844
# Modularity score: 0.164
# Persona assortativity: -0.00124846436757341
#
# Local metrics ...
#
#
# Statistical check (metrics vs. persona) ...
#
# in_degree statistics: p = 0.1513
# out_degree statistics: p = 0.4460
# total_degree statistics: p = 0.5381
# betweenness statistics: p = 0.3423
# eigenvector statistics: p = 0.4188
# pagerank statistics: p = 0.2167
# kcore statistics: p = 0.5420

# %%
summary_5
# Out:
#            n_nodes  mean_in_degree  mean_out_degree  mean_total_degree  \
# persona
# Persona_1      214       13.266355        12.742991          26.009346
# Persona_2      225       10.177778        10.884444          21.062222
# Persona_3      235       10.795745        10.123404          20.919149
# Persona_4      229       10.838428        11.323144          22.161572
#
#            mean_betweenness  median_betweenness  mean_pagerank  mean_kcore  \
# persona
# Persona_1          0.002202            0.000376       0.001262   11.126168
# Persona_2          0.001970            0.000112       0.001023    9.813333
# Persona_3          0.001878            0.000091       0.001073    9.336170
# Persona_4          0.001830            0.000165       0.001081   10.301310
#
#            pagerank_ratio    Simulation
# persona
# Persona_1        1.139766  Simulation_5
# Persona_2        0.923433  Simulation_5
# Persona_3        0.969242  Simulation_5
# Persona_4        0.976183  Simulation_5

# %% [markdown]
# ## Analysis

# %%
global_metrics_summary = pd.concat([global_metrics_b1,
                                    global_metrics_b2,
                                    global_metrics_b3,
                                    global_metrics_3,
                                    global_metrics_4,
                                    global_metrics_5], axis=1)

global_metrics_summary
# Out:
#                        Simulation_b1  Simulation_b2  Simulation_b3  \
# Metric
# Mean degree                22.937220      23.662570      23.077441
# Density                     0.012872       0.013234       0.012965
# Diameter                    6.000000       7.000000       7.000000
# Avg. shortest path          2.822344       2.808779       2.801039
# Modularity                  0.155696       0.156704       0.160809
# Persona assortativity      -0.002826      -0.002846       0.002137
#
#                        Simulation_3  Simulation_4  Simulation_5
# Metric
# Mean degree               22.937220     23.146396     22.476190
# Density                    0.012872      0.013048      0.012459
# Diameter                   6.000000      6.000000      6.000000
# Avg. shortest path         2.822344      2.788639      2.843675
# Modularity                 0.158728      0.158381      0.163759
# Persona assortativity     -0.002826     -0.001287     -0.001248

# %%
def compare_persona_across_simulations(summaries, num_persona):
    """
    Compares persona across simulations. Creates summary table for each persona and returns them.
    """
    persona_tables = []

    for i in range(num_persona):
        tables = []

        for summary in summaries:
            tables.append(summary.loc[f"Persona_{i+1}"])

        table = pd.concat(tables, axis=1)
        persona_tables.append(table)

    print(f"Number of persona tables: {len(persona_tables)}")

    return persona_tables

# %%
summaries = [summary_b1, summary_b2, summary_b3, summary_3, summary_4, summary_5]
tables = compare_persona_across_simulations(summaries, num_persona=4)

tab = tables[0]
# Out:
# Number of persona tables: 4

# %%
tab
# Out:
#                         Persona_1      Persona_1      Persona_1     Persona_1  \
# n_nodes                       214            215            223           214
# mean_in_degree          13.813084      14.418605       13.64574     13.813084
# mean_out_degree         13.084112      14.190698      13.735426     13.084112
# mean_total_degree       26.897196      28.609302      27.381166     26.897196
# mean_betweenness         0.002148       0.002125       0.002309      0.002148
# median_betweenness       0.000378       0.000182       0.000375      0.000378
# mean_pagerank            0.001309       0.001313       0.001275      0.001309
# mean_kcore              11.574766      12.413953      11.941704     11.574766
# pagerank_ratio           1.167879        1.17488       1.136342      1.167879
# Simulation          Simulation_b1  Simulation_b2  Simulation_b3  Simulation_3
#
#                        Persona_1     Persona_1
# n_nodes                      212           214
# ...

# %%
(tab.loc['Simulation'])
# Out:
# Persona_1    Simulation_b1
# Persona_1    Simulation_b2
# Persona_1    Simulation_b3
# Persona_1     Simulation_3
# Persona_1     Simulation_4
# Persona_1     Simulation_5
# Name: Simulation, dtype: object

# %%
tab = tab.reset_index()

# %% [markdown]
# ## Representative simulation analysis

# %% [markdown]
# Example simulation to describe in the report.
#
# ***Simulation b1*** - some differences between personae position in network structure are observed.
#
# We do EDA and null model validation on it.

# %% [markdown]
# ### EDA

# %%
# create graph
G, G_lcc = create_graph(followb1)

nx.set_node_attributes(G, persona_dict, "persona")
nx.set_node_attributes(G_lcc, persona_dict, "persona")
# Out:
# Number of nodes: 892
# Number of edges: 10230
# Number of connective components: 1
# Components sizes: [892]

# %%
users = pd.read_sql("SELECT * FROM user_mgmt", connb1)
users.drop([0], inplace=True)
users.head()
# Out:
#    id         username                       email         password  \
# 1   2  CynthiaSchwartz  CynthiaSchwartz@ysocial.it  CynthiaSchwartz
# 2   3     WayneHancock     WayneHancock@ysocial.it     WayneHancock
# 3   4    HeatherTucker    HeatherTucker@ysocial.it    HeatherTucker
# 4   5        JuanBrown        JuanBrown@ysocial.it        JuanBrown
# 5   6        JohnStark        JohnStark@ysocial.it        JohnStark
#
#          user_type   leaning  age                   oe                    co  \
# 1  llama3.2:latest  democrat   27  consistent/cautious   efficient/organized
# 2  llama3.2:latest  democrat   57    inventive/curious   efficient/organized
# 3  llama3.2:latest  democrat   16    inventive/curious  extravagant/careless
# 4  llama3.2:latest  democrat   62  consistent/cautious  extravagant/careless
# 5  llama3.2:latest  democrat   52  consistent/cautious  extravagant/careless
#
#                    ex  ...     frecsys_type round_actions  gender nationality  \
# ...

# %%
users[['daily_activity_level']].value_counts()
# Out:
# daily_activity_level
# 1                       374
# 2                       291
# 3                       203
# 4                       105
# 5                        27
# Name: count, dtype: int64

# %%
users[['profession']].value_counts()
# Out:
# profession
# Student             150
# Clown                33
# Textile Worker       28
# Factory Worker       21
# Military Officer     19
#                    ...
# Dog Walker            2
# Fortune Teller        1
# Busker                1
# Pharmacist            1
# Photographer          1
# Name: count, Length: 121, dtype: int64

# %%
users[['activity_profile']].value_counts()
# Out:
# activity_profile
# Coffee Break User    411
# Community Builder    395
# Always On            194
# Name: count, dtype: int64

# %% [markdown]
# Agents:
# - leaning: 100% democrat
# - education level: 100% master
# - each of 5 personality features has distribution approximately 50%/50%
# - 100% English
# - 100% American
# - gender: 519 female, 481 male
# - activity profile: 40% coffee break users, 40% community builder, 20% always on

# %%
plt.figure(figsize=[8,5])
plt.hist(users[['age']], bins=20)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %%
degree = [dict(G.degree()).get(n, 0) for n in G.nodes()]
degree.sort(reverse=True)
degree[:10]
# Out:
# [312, 297, 282, 270, 255, 224, 223, 219, 213, 208]

# %%
fig, ax = plt.subplots(figsize=(8, 5), facecolor="white")
sns.histplot([dict(G.degree()).get(n, 0) for n in G.nodes()], bins=50, kde=True, ax=ax)
ax.set_title("Total degree distribution", fontsize=14, weight="bold", pad=12)
ax.set_xlabel("Degree", fontsize=12)
ax.set_ylabel("Count", fontsize=12)
ax.grid(axis="x", linestyle="--", alpha=0.1)
sns.despine(left=True, bottom=True)
plt.show()

# %%
personaeb1.head()
# Out:
#    id             openness     conscientiousness        extroversion  \
# 1   2  consistent/cautious   efficient/organized   solitary/reserved
# 2   3    inventive/curious   efficient/organized  outgoing/energetic
# 3   4    inventive/curious  extravagant/careless  outgoing/energetic
# 4   5  consistent/cautious  extravagant/careless   solitary/reserved
# 5   6  consistent/cautious  extravagant/careless   solitary/reserved
#
#             agreeableness          neuroticism    age        profession  \
# 1  friendly/compassionate  resilient/confident  young    Skilled_Trades
# 2  friendly/compassionate    sensitive/nervous    old    Skilled_Trades
# 3     critical/judgmental    sensitive/nervous  young  Science_Academia
# 4     critical/judgmental  resilient/confident    old          Security
# 5  friendly/compassionate    sensitive/nervous    old  Science_Academia
#
#    gender   leaning education_level    persona
# 1  female  democrat          master  Persona_2
# ...

# %%
personaeb1[['profession']].value_counts()
# Out:
# profession
# Science_Academia     232
# Law_Finance_Admin    131
# Retail_Service       130
# Skilled_Trades       113
# Arts_Media            88
# Technology            73
# Security              66
# Sport                 40
# Healthcare            38
# Transport             37
# Agriculture           28
# Alternative           24
# Name: count, dtype: int64

# %% [markdown]
# ### Null model validation

# %%
# def persona_permutation_test(G, n_perm=100):
#     nodes = list(G.nodes())
#     personas = [G.nodes[n]["persona"] for n in nodes]
#
#     null_stats = []
#
#     for _ in range(n_perm):
#         random.shuffle(personas)
#
#         perm_mapping = dict(zip(nodes, personas))
#         nx.set_node_attributes(G, perm_mapping, "persona")
#
#         stat = nx.attribute_assortativity_coefficient(G, "persona")
#         null_stats.append(stat)
#
#     return np.array(null_stats)
#
#
# null = persona_permutation_test(G)
# p_value = (null >= observed).mean()
